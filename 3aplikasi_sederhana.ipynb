# %% [markdown]
# <a href="https://colab.research.google.com/github/afnangama-max/KKA-X-Semester-1/blob/main/3aplikasi_sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Nama : Afnan Maulana Gama
# #Kelas : X-11
# #Absen : 02
# #kelompok : kinjeng pintar

# %% [markdown]
# ##Aplikasi sederhana menghitung volume bola

# %%
jari_jari = int(input("masukan jari-jari dari bola(cm): "))
pi = 22/7
volume_bola = 4/3 * pi * jari_jari**3
print(f"volume bola adalah {volume_bola} cm^3. ")
# Out:
# masukan jari-jari dari bola(cm): 7
# volume bola adalah 1437.333333333333 cm^3.

# %% [markdown]
# ##Aplikasi sederhana menghitung volume tabung

# %%
jari_jari = float(input("Masukan jari-jari alas tabung (cm): "))
tinggi = float(input("Masukan tinggi tabung (cm): "))
pi = 22/7
volume_tabung = pi * jari_jari**2 * tinggi
print(f"volume tabung adalah {volume_tabung} cm^3. ")
# Out:
# Masukan jari-jari alas tabung (cm): 7
# Masukan tinggi tabung (cm): 10
# volume tabung adalah 1540.0 cm^3.

# %% [markdown]
# ##Operator perbandingan

# %%
6>=6
# Out:
# True

# %%
8==9
# Out:
# False

# %%
8!=9
# Out:
# True

# %%
8<10
# Out:
# True

# %%
8>10
# Out:
# False

# %% [markdown]
# ##Operator logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<=1 or 2!=2)
# Out:
# False

# %%
print(not(0==1 and 1!=1))
# Out:
# True

# %%
print(not(5<10 or 5<=10))
# Out:
# False
